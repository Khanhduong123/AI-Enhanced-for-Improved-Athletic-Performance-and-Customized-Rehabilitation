# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv("new_BODY_coordinates.csv")
# drop z 
df = df.drop(['BODY_1_z', 'BODY_2_z', 'BODY_3_z', 'BODY_4_z'], axis=1)
X1 = df.drop("label", axis=1)
y1 = df["label"]
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.2, random_state=42)
X_train1.to_csv("pose_data_csv/BODY/train/X_train.csv", index=False)
X_test1.to_csv("pose_data_csv/BODY/test/X_test.csv", index=False)
y_train1.to_csv("pose_data_csv/BODY/train/y_train.csv", index=False)
y_test1.to_csv("pose_data_csv/BODY/test/y_test.csv", index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
df = pd.read_csv("pose_data_csv\BODY_coordinates.csv")
df_x = df[[i for i in df.columns if "x" in i] + ["label"]]
df_y = df[[i for i in df.columns if "y" in i] + ["label"]]

mii_x = df_x.drop("label", axis=1).values.min(axis=1, keepdims=True)
mii_y = df_y.drop("label", axis=1).values.min(axis=1, keepdims=True)
mxx_x = df_x.drop("label", axis=1).values.max(axis=1, keepdims=True)
mxx_y = df_y.drop("label", axis=1).values.max(axis=1, keepdims=True)
df_x = (df_x - mii_x) / (mxx_x - mii_x)
df_y = (df_y - mii_y) / (mxx_y - mii_y)
for i in range(1,5):
    plt.scatter(df_x[f"BODY_{i}_x"], df_y[f"BODY_{i}_y"], c=df["label"])

for i in range(1,5):
    df[f'BODY_{i}_x'] = df_x[f'BODY_{i}_x']
    df[f'BODY_{i}_y'] = df_y[f'BODY_{i}_y']
df.to_csv("./new_BODY_coordinates.csv", index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
df = pd.read_csv("pose_data_csv\FACE_NECK_coordinates.csv")
df_x = df[[i for i in df.columns if "x" in i] + ["label"]]
df_y = df[[i for i in df.columns if "y" in i] + ["label"]]

mii_x = df_x.drop("label", axis=1).values.min(axis=1, keepdims=True)
mii_y = df_y.drop("label", axis=1).values.min(axis=1, keepdims=True)
mxx_x = df_x.drop("label", axis=1).values.max(axis=1, keepdims=True)
mxx_y = df_y.drop("label", axis=1).values.max(axis=1, keepdims=True)
df_x = (df_x - mii_x) / (mxx_x - mii_x)
df_y = (df_y - mii_y) / (mxx_y - mii_y)
for i in range(1,12):
    plt.scatter(df_x[f"FACE_NECK_{i}_x"], df_y[f"FACE_NECK_{i}_y"], c=df["label"])

for i in range(1,12):
    df[f'FACE_NECK_{i}_x'] = df_x[f'FACE_NECK_{i}_x']
    df[f'FACE_NECK_{i}_y'] = df_y[f'FACE_NECK_{i}_y']
df.to_csv("./new_FACE_NECK_coordinates.csv", index=False)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv("new_FACE_NECK_coordinates.csv")
# drop z coodinates
for i in range(1,12):
    df = df.drop(f"FACE_NECK_{i}_z", axis=1)  
X1 = df.drop("label", axis=1)
y1 = df["label"]
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.2, random_state=42)
X_train1.to_csv("pose_data_csv/FACE_NECK/train/X_train.csv", index=False)
X_test1.to_csv("pose_data_csv/FACE_NECK/test/X_test.csv", index=False)
y_train1.to_csv("pose_data_csv/FACE_NECK/train/y_train.csv", index=False)
y_test1.to_csv("pose_data_csv/FACE_NECK/test/y_test.csv", index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
df = pd.read_csv("pose_data_csv\LEFT_ARM_coordinates.csv")
df_x = df[[i for i in df.columns if "x" in i] + ["label"]]
df_y = df[[i for i in df.columns if "y" in i] + ["label"]]

mii_x = df_x.drop("label", axis=1).values.min(axis=1, keepdims=True)
mii_y = df_y.drop("label", axis=1).values.min(axis=1, keepdims=True)
mxx_x = df_x.drop("label", axis=1).values.max(axis=1, keepdims=True)
mxx_y = df_y.drop("label", axis=1).values.max(axis=1, keepdims=True)
df_x = (df_x - mii_x) / (mxx_x - mii_x)
df_y = (df_y - mii_y) / (mxx_y - mii_y)
for i in range(1,7):
    plt.scatter(df_x[f"LEFT_ARM_{i}_x"], df_y[f"LEFT_ARM_{i}_y"], c=df["label"])

for i in range(1,7):
    df[f'LEFT_ARM_{i}_x'] = df_x[f'LEFT_ARM_{i}_x']
    df[f'LEFT_ARM_{i}_y'] = df_y[f'LEFT_ARM_{i}_y']
df.to_csv("./new_LEFT_ARM_coordinates.csv", index=False)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv("new_LEFT_ARM_coordinates.csv")
# drop z coodinates
for i in range(1,7):
    df = df.drop(f"LEFT_ARM_{i}_z", axis=1)  
X1 = df.drop("label", axis=1)
y1 = df["label"]
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.2, random_state=42)
X_train1.to_csv("pose_data_csv/LEFT_ARM/train/X_train.csv", index=False)
X_test1.to_csv("pose_data_csv/LEFT_ARM/test/X_test.csv", index=False)
y_train1.to_csv("pose_data_csv/LEFT_ARM/train/y_train.csv", index=False)
y_test1.to_csv("pose_data_csv/LEFT_ARM/test/y_test.csv", index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
df = pd.read_csv("pose_data_csv\RIGHT_ARM_coordinates.csv")
df_x = df[[i for i in df.columns if "x" in i] + ["label"]]
df_y = df[[i for i in df.columns if "y" in i] + ["label"]]

mii_x = df_x.drop("label", axis=1).values.min(axis=1, keepdims=True)
mii_y = df_y.drop("label", axis=1).values.min(axis=1, keepdims=True)
mxx_x = df_x.drop("label", axis=1).values.max(axis=1, keepdims=True)
mxx_y = df_y.drop("label", axis=1).values.max(axis=1, keepdims=True)
df_x = (df_x - mii_x) / (mxx_x - mii_x)
df_y = (df_y - mii_y) / (mxx_y - mii_y)
for i in range(1,7):
    plt.scatter(df_x[f"RIGHT_ARM_{i}_x"], df_y[f"RIGHT_ARM_{i}_y"], c=df["label"])

for i in range(1,7):
    df[f'RIGHT_ARM_{i}_x'] = df_x[f'RIGHT_ARM_{i}_x']
    df[f'RIGHT_ARM_{i}_y'] = df_y[f'RIGHT_ARM_{i}_y']
df.to_csv("./new_RIGHT_ARM_coordinates.csv", index=False)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv("new_RIGHT_ARM_coordinates.csv")
# drop z coodinates
for i in range(1,7):
    df = df.drop(f"RIGHT_ARM_{i}_z", axis=1)  
X1 = df.drop("label", axis=1)
y1 = df["label"]
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.2, random_state=42)
X_train1.to_csv("pose_data_csv/RIGHT_ARM/train/X_train.csv", index=False)
X_test1.to_csv("pose_data_csv/RIGHT_ARM/test/X_test.csv", index=False)
y_train1.to_csv("pose_data_csv/RIGHT_ARM/train/y_train.csv", index=False)
y_test1.to_csv("pose_data_csv/RIGHT_ARM/test/y_test.csv", index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
df = pd.read_csv("pose_data_csv\RIGHT_LEG_coordinates.csv")
df_x = df[[i for i in df.columns if "x" in i] + ["label"]]
df_y = df[[i for i in df.columns if "y" in i] + ["label"]]

mii_x = df_x.drop("label", axis=1).values.min(axis=1, keepdims=True)
mii_y = df_y.drop("label", axis=1).values.min(axis=1, keepdims=True)
mxx_x = df_x.drop("label", axis=1).values.max(axis=1, keepdims=True)
mxx_y = df_y.drop("label", axis=1).values.max(axis=1, keepdims=True)
df_x = (df_x - mii_x) / (mxx_x - mii_x)
df_y = (df_y - mii_y) / (mxx_y - mii_y)
for i in range(1,6):
    plt.scatter(df_x[f"RIGHT_LEG_{i}_x"], df_y[f"RIGHT_LEG_{i}_y"], c=df["label"])

for i in range(1,6):
    df[f'RIGHT_LEG_{i}_x'] = df_x[f'RIGHT_LEG_{i}_x']
    df[f'RIGHT_LEG_{i}_y'] = df_y[f'RIGHT_LEG_{i}_y']
df.to_csv("./new_RIGHT_LEG_coordinates.csv", index=False)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv("new_RIGHT_LEG_coordinates.csv")
# drop z coodinates
for i in range(1,6):
    df = df.drop(f"RIGHT_LEG_{i}_z", axis=1)  
X1 = df.drop("label", axis=1)
y1 = df["label"]
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.2, random_state=42)
X_train1.to_csv("pose_data_csv/RIGHT_LEG/train/X_train.csv", index=False)
X_test1.to_csv("pose_data_csv/RIGHT_LEG/test/X_test.csv", index=False)
y_train1.to_csv("pose_data_csv/RIGHT_LEG/train/y_train.csv", index=False)
y_test1.to_csv("pose_data_csv/RIGHT_LEG/test/y_test.csv", index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
df = pd.read_csv("pose_data_csv\LEFT_LEG_coordinates.csv")
df_x = df[[i for i in df.columns if "x" in i] + ["label"]]
df_y = df[[i for i in df.columns if "y" in i] + ["label"]]

mii_x = df_x.drop("label", axis=1).values.min(axis=1, keepdims=True)
mii_y = df_y.drop("label", axis=1).values.min(axis=1, keepdims=True)
mxx_x = df_x.drop("label", axis=1).values.max(axis=1, keepdims=True)
mxx_y = df_y.drop("label", axis=1).values.max(axis=1, keepdims=True)
df_x = (df_x - mii_x) / (mxx_x - mii_x)
df_y = (df_y - mii_y) / (mxx_y - mii_y)
for i in range(1,6):
    plt.scatter(df_x[f"LEFT_LEG_{i}_x"], df_y[f"LEFT_LEG_{i}_y"], c=df["label"])

for i in range(1,6):
    df[f'LEFT_LEG_{i}_x'] = df_x[f'LEFT_LEG_{i}_x']
    df[f'LEFT_LEG_{i}_y'] = df_y[f'LEFT_LEG_{i}_y']
df.to_csv("./new_LEFT_LEG_coordinates.csv", index=False)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv("new_LEFT_LEG_coordinates.csv")
# drop z coodinates
for i in range(1,6):
    df = df.drop(f"LEFT_LEG_{i}_z", axis=1)  
X1 = df.drop("label", axis=1)
y1 = df["label"]
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.2, random_state=42)
X_train1.to_csv("pose_data_csv/LEFT_LEG/train/X_train.csv", index=False)
X_test1.to_csv("pose_data_csv/LEFT_LEG/test/X_test.csv", index=False)
y_train1.to_csv("pose_data_csv/LEFT_LEG/train/y_train.csv", index=False)
y_test1.to_csv("pose_data_csv/LEFT_LEG/test/y_test.csv", index=False)
