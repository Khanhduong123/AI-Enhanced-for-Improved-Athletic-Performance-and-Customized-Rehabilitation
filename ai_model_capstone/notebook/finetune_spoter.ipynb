# %%
import sys
import os
print(sys.path.append(os.path.abspath("..")))
# Out:
# None

# %%
a

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from core.model import SPOTER
from core.dataset import YogaDataset
from torch.utils.data import DataLoader

# %%
ls -lh ./checkpoints/spoter/pretrain/best_checkpoint.pt
# Out:
# Parameter format not correct - "checkpoints".

# %%
checkpoint_path = "../checkpoints/spoter/pretrain/best_checkpoint.pt"
checkpoint = torch.load(checkpoint_path, map_location="cuda" if torch.cuda.is_available() else "cpu")
checkpoint
# json_folder = "../data/keypoints/private_data/train"
# batch_size = 4
# dataset = YogaDataset(json_folder, max_frames=100)
# trainloader = DataLoader(dataset, batch_size, shuffle=True)

# # Lấy các tham số mô hình cũ
# old_num_classes = checkpoint['model']['linear_class.weight'].shape[0]  # Lấy số classes từ trọng số cũ
# hidden_dim = checkpoint['model']['input_projection.weight'].shape[0]  # Giữ hidden_dim cũ

# # Khởi tạo mô hình với num_classes mới (2)
# new_num_classes = 2
# model = SPOTER(num_classes=new_num_classes, hidden_dim=hidden_dim, num_heads=9, encoder_layers=6, decoder_layers=6)

# # Load trọng số cũ, bỏ qua lớp classification (`linear_class`)
# state_dict = checkpoint['model']
# state_dict.pop("linear_class.weight")  # Xóa trọng số lớp classification cũ
# state_dict.pop("linear_class.bias")    # Xóa bias của lớp classification cũ

# # Load lại phần còn lại của mô hình
# model.load_state_dict(state_dict, strict=False)

# # Khởi tạo lại `linear_class` với num_classes mới
# model.linear_class = nn.Linear(hidden_dim, new_num_classes)
# nn.init.xavier_uniform_(model.linear_class.weight)  # Khởi tạo lại trọng số mới
# model.linear_class.bias.data.zero_()  # Reset bias

# # Đưa model về device (GPU nếu có)
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model.to(device)

# # Thiết lập Loss và Optimizer cho Finetune
# criterion = nn.CrossEntropyLoss()
# optimizer = optim.Adam(model.parameters(), lr=0.0001)

# # Tiếp tục huấn luyện (Fine-tuning)
# for epoch in range(10):  # Chạy 10 epochs (có thể thay đổi)
#     model.train()
#     for inputs, labels in trainloader:  # Giả sử `trainloader` đã được định nghĩa
#         inputs, labels = inputs.to(device), labels.to(device)

#         optimizer.zero_grad()
#         outputs = model(inputs)
#         loss = criterion(outputs, labels)
#         loss.backward()
#         optimizer.step()

#     print(f"Epoch {epoch+1}: Loss = {loss.item():.4f}")

# # Lưu lại model đã fine-tune
# torch.save({"model": model.state_dict()}, "fine_tuned_checkpoint.pt")
# print("✅ Fine-tuning hoàn thành và đã lưu mô hình mới!")
# Out:
# C:\Users\KhanhDuong\AppData\Local\Temp\ipykernel_2088\103777404.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...
